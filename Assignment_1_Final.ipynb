# %% [markdown]
# <a href="https://colab.research.google.com/github/Mirucla/Applied-Data-Management/blob/main/Assignment_1_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/new.csv')

# %%
df
# Out:
#         customer_id  main_account_loan_no  main_account_active_loan_no  \
# 0           6280549                     4                            3
# 1           5301591                     2                            0
# 2           6319892                     0                            0
# 3           5468887                     0                            0
# 4           4937996                     6                            4
# ...             ...                   ...                          ...
# 199712      6515011                     1                            1
# 199713      6487610                     0                            0
# 199714      5151943                     0                            0
# 199715      6110885                     7                            4
# 199716      4620205                     3                            1
#
#         main_account_overdue_no  main_account_outstanding_loan  \
# ...

# %%
import matplotlib as plt 
df['sub_account_disbursed_loan'].hist()
